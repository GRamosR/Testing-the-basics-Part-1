# %%
#This say Hello to Python
#print() is a funtion, need an argument to  intruct Python what show you
print("Hello, Python!")

#This is calling "sys"(that is a specific parameters and funtions, that include "version parameter")
#Need explicity "import" word to call the parameters or funtions
import sys
print(sys.version)

#This will display an error message (Function Error)
#frint("Hello, Python!")

#This will display an error message (Syntax Error)
#print("Hello, Python!)

#What printed, sysntax error and not printed
print("\nThis will be printed")
#fprint("This cause an error")
#print ("This will be not printed")

#-------------------------------------------------------
#Exercise (Objects and types)
#integer
11

#float
3.14

#string
"Hello, World!"

#Using "type()" funtion
#print type() of 12
print (type(12))

#print type() of 3.14
print (type(3.14))

#print type() of Hello, World!
print (type("Hello, World!\n\n"))

#-------------------------------------------
#Converting Integer to float 13 
float(13)

#Converting float to integer 7.1 and check his type()
type(int(7.1))

#Try converting a String to Integer
#print (int("1 or 2 people"))

str('1.10')

#----------------------------------------------
#Boolean Type()
#Check True type()
type(True)
#Check False type()
type(False)

#Storing a value in a variable and print then
x = 45+8+9+41
x

#Creating a complicate expression
total_hours = (60*8)+145/9 #total hours in a single expression
print("\n")
print(total_hours) #Leaving 2 spaces lines and then show expression

#Expression and Variables
#asigning Blues to variables
x = 56+2+13+103-95 #Storing values to x
y = (45*13)+14/5   #Storing values to y
z = x + y          #Initializing z

print(z)        #Showing Value of z
# Out:
# Hello, Python!
# 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)]
#
# This will be printed
# <class 'int'>
# <class 'float'>
# <class 'str'>
#
#
# 496.1111111111111
# 666.8
